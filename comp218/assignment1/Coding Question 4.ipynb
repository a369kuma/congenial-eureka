# %%
income = float(input("Enter total annual income: "))

# %%
brackets = [
    (253414, 0.33),
    (177882, 0.29),
    (114750, 0.26),
    (57375, 0.205),
    (0, 0.145)
]

# %%
if income <= 57375:
    tax = income * 0.145
elif income <= 114750:
    tax = (57375 * 0.145) + (income - 57375) * 0.205
elif income <= 177882:
    tax = (57375 * 0.145) + (57375 * 0.205) + (income - 114750) * 0.26
elif income <= 253414:
    tax = (57375 * 0.145) + (57375 * 0.205) + (63132 * 0.26) + (income - 177882) * 0.29
else:
    tax = (57375 * 0.145) + (57375 * 0.205) + (63132 * 0.26) + (75532 * 0.29) + (income - 253414) * 0.33

print(f"Total federal income tax to be paid: ${tax:.2f}")
# Out:
# Total federal income tax to be paid: $73773.23
