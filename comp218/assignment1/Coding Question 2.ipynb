# %%
print("    ---------")
# Out:
#     ---------

# %%
for i in range(3, 0, -1):
    spaces = " " * i
    print(f"{spaces}/       /")
# Out:
#    /       /
#   /       /
#  /       /

# %%
print("---------")
# Out:
# ---------
